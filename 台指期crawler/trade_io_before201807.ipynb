# %%
#整體操作流程:先用selenium找到要找頁面，用katalon可以記錄點按的流程，再用katalon匯出成python語言，
##再來是要找的資料，用selenium找xpath然後用網路上看到的選取方法//td[]之類的，選到自己要的資料，把它存在一個var形式會是list
##用反向輸出.index()找到所要的資料的index，再用var[i].text輸出要的數字，.text才能顯示數字
##打開csv跟寫入csv參考內文，一個row最後要\n
##用if判斷是否是交易日，交易日len(trade)會大於93

#下面這段用來找數字的位置，隔了一段時間數字會換位子
#for s in range(num):
        #ttrade.append(trade[s].text)
    #print(ttrade.index("210756"))

# %%
import re
import csv
from selenium import webdriver
from selenium.webdriver.support.ui import Select
driver = webdriver.Chrome()
driver.get("http://www.taifex.com.tw/cht/3/futDailyMarketReport")

# trade = driver.find_elements_by_xpath('//td[@class="12bk"]')
# date = driver.find_elements_by_xpath('//h3')
#datel=[]
ttrade=[]
#num = len(trade)
        
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='日期：'])[1]/following::img[1]").click()
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='服務信箱(service@taifex.com.tw)'])[1]/following::span[1]").click()
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='服務信箱(service@taifex.com.tw)'])[1]/following::span[1]").click()
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='服務信箱(service@taifex.com.tw)'])[1]/following::span[1]").click()
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='服務信箱(service@taifex.com.tw)'])[1]/following::span[1]").click()
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='服務信箱(service@taifex.com.tw)'])[1]/following::span[1]").click()
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='服務信箱(service@taifex.com.tw)'])[1]/following::span[1]").click()
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='服務信箱(service@taifex.com.tw)'])[1]/following::span[1]").click()
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='服務信箱(service@taifex.com.tw)'])[1]/following::span[1]").click()
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='服務信箱(service@taifex.com.tw)'])[1]/following::span[1]").click()
driver.find_element_by_xpath(u"(.//*[normalize-space(text()) and normalize-space(.)='服務信箱(service@taifex.com.tw)'])[1]/following::span[1]").click()
driver.find_element_by_link_text("29").click()
driver.find_element_by_id("button").click()
    
#晚上操作就不用這段

# %%
with open('trade_io.csv','w') as f:
    f.write("date, trade, io \n")

# %%
for i in range(2000):
    
    driver.find_element_by_id("button3").click()
    
    trade = driver.find_elements_by_xpath('//td[@class="12bk"]')
    date = driver.find_elements_by_xpath('//h3')
    num = len(trade)
    
    if num>90:
        #datel.append(date[0].text)           #把日期先加到datel list      #print(trade[93].text)
        with open('trade_io.csv','a') as h:
                h.write(str(re.findall(r"(\d{4}/\d{1,2}/\d{1,2})",date[0].text)) + "," + trade[78].text + "," + trade[79].text + "\n")  
        #一次打出當次的日期，且用正則表達打出只有數字 #後面只能下午等資料更新才能使用
        print(trade[79].text)
    else:
        
        continue
        #for s in range(num):
            #h.write(","+trade[93].text+","+trade[94].text+"\n") 
driver.close()
# Out:
# 106020
# 101958
# 100696
# 100133
# 99105
# 96438
# 107506
# 111591
# 111195
# 105285
# 106747
# 107456
# 108428
# 108511
# 109476
# 112680
# 105924
# 108949
# 100649
# 98600
# 99983
# 100645
# 101694
# 101540
# 100094
# 96555
# 94229
# 95313
# 91547
# 90594
# 102479
# 103582
# 103225
# 99850
# 96274
# 96184
# 97095
# 93816
# 93210
# 95983
# 93952
# 93708
# 94320
# 96481
# 97034
# 100847
# 100025
# 98069
# 104151
# 102859
# 104954
# 103927
# 102197
# 99097
# 103435
# 104073
# 101699
# 100328
# 101739
# 100393
# 100875
# 100698
# 102524
# 102133
# 102855
# 101112
# 95979
# 108125
# 118407
# 112083
# 110011
# 114420
# 108822
# 113198
# 111796
# 106295
# 107794
# 104418
# 105346
# 103223
# 100353
# 100693
# 99593
# 99523
# 100317
# 93789
# 113157
# 109854
# 111221
# 109787
# 107142
# 112381
# 113179
# 116634
# 116540
# 113159
# 112394
# 111826
# 110807
# 112107
# 108238
# 111966
# 110045
# 108572
# 102817
# 121950
# 122727
# 116014
# 120395
# 114566
# 115389
# 116464
# 114756
# 112653
# ...

# %%
#datel.append(date[0].text)
                                    #ttrade=[]
                                    #for i in range(num):
                                            #ttrade.append(trade[i].text)
                                    
                                    #print(ttrade.index('148916'))
                                    #print(ttrade.index('119463'))
                                    #找到index 93=總成交量 94=總未平倉量，屬於trade；index1=日期屬於date
##for s in datel:
    ##print(re.findall(r"(\d{4}/\d{1,2}/\d{1,2})",s))
# Out:
# ['2019/04/17']
